# %% [markdown]
# # Challenge Set 1:  MTA Turnstile Data

# %%
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
import datetime

# %% [markdown]
# #### Exercise 1.1
#
# - Open up a new Jupyter notebook
# - Download a few MTA turnstile data files
# - Open up a file, use csv reader to read it, make a python dict where
#   there is a key for each (C/A, UNIT, SCP, STATION). These are the
#   first four columns. The value for this key should be a list of
#   lists. Each list in the list is the rest of the columns in a
#   row. For example, one key-value pair should look like
#
#
# {    ('A002','R051','02-00-00','LEXINGTON AVE'):
# [
# ['NQR456', 'BMT', '01/03/2015', '03:00:00', 'REGULAR', '0004945474', '0001675324'],
# ['NQR456', 'BMT', '01/03/2015', '07:00:00', 'REGULAR', '0004945478', '0001675333'],
# ['NQR456', 'BMT', '01/03/2015', '11:00:00', 'REGULAR', '0004945515', '0001675364'],
# ...
# ]
# }

# %%
# Source: http://web.mta.info/developers/turnstile.html
def get_data(week_nums):
    # base url
    url = "http://web.mta.info/developers/data/nyct/turnstile/turnstile_{}.txt"
    dfs = []
    for week_num in week_nums:
        # concat our week onto url.. 
        file_url = url.format(week_num)
        dfs.append(pd.read_csv(file_url))
    return pd.concat(dfs)
        
week_nums = [170610, 170617, 170624, 170701]
turnstiles_df = get_data(week_nums)

# %%
# aha!  an example where we do not have a unique index ??  hmmm..  
len(turnstiles_df)
# Out:
# 789677

# %%
turnstiles_df.tail()
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 197416  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/30/2017
# 197417  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/30/2017
# 197418  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/30/2017
# 197419  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/30/2017
# 197420  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/30/2017
#
#             TIME     DESC  ENTRIES  \
# 197416  07:17:19  REGULAR     5554
# 197417  09:00:00  REGULAR     5554
# 197418  13:00:00  REGULAR     5554
# 197419  17:00:00  REGULAR     5554
# 197420  21:00:00  REGULAR     5554
#
#         EXITS
# 197416                                                301
# 197417                                                301
# 197418                                                301
# 197419                                                301
# 197420                                                301

# %%
turnstiles_df.loc[1]
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/03/2017  04:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/10/2017  04:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/17/2017  04:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/24/2017  04:00:00
#
#       DESC  ENTRIES  \
# 1  REGULAR  6203674
# 1  REGULAR  6215284
# 1  REGULAR  6224850
# 1  REGULAR  6233696
#
#    EXITS
# 1                                            2101230
# 1                                            2104303
# 1                                            2107322
# 1                                            2110445

# %%
turnstiles_df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')

# %%
# major space issue on exits
turnstiles_df.columns = [column.strip() for column in turnstiles_df.columns]

# %%
turnstiles_df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES', 'EXITS'],
#       dtype='object')

# %%
turnstiles_df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/03/2017  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/03/2017  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/03/2017  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/03/2017  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/03/2017  16:00:00
#
#       DESC  ENTRIES    EXITS
# 0  REGULAR  6203652  2101226
# 1  REGULAR  6203674  2101230
# 2  REGULAR  6203688  2101260
# 3  REGULAR  6203769  2101343
# 4  REGULAR  6203987  2101401

# %% [markdown]
# #### Exercise 1.2
#
# - Let's turn this into a time series.
#
#  For each key (basically the control area, unit, device address and
#  station of a specific turnstile), have a list again, but let the list
#  be comprised of just the point in time and the count of entries.
#
# **This basically means keeping only the date, time, and entries fields
# in each list.** You can convert the date and time into datetime objects
# -- That is a python class that represents a point in time. You can
# combine the date and time fields into a string and use the
# [dateutil](https://labix.org/python-dateutil) module to convert it
# into a datetime object. For an example check
# [this StackOverflow question](http://stackoverflow.com/questions/23385003/attributeerror-when-using-import-dateutil-and-dateutil-parser-parse-but-no).
#
# Your new dict should look something like
#
# {    ('A002','R051','02-00-00','LEXINGTON AVE'):
# [
# [datetime.datetime(2013, 3, 2, 3, 0), 3788],
# [datetime.datetime(2013, 3, 2, 7, 0), 2585],
# [datetime.datetime(2013, 3, 2, 12, 0), 10653],
# [datetime.datetime(2013, 3, 2, 17, 0), 11016],
# [datetime.datetime(2013, 3, 2, 23, 0), 10666],
# [datetime.datetime(2013, 3, 3, 3, 0), 10814],
# [datetime.datetime(2013, 3, 3, 7, 0), 10229],
# ...
# ],
# ....
# }

# %%
turnstiles_df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES', 'EXITS'],
#       dtype='object')

# %%
from datetime import datetime as dt

# %%
# develop filter, .. 
mask = ((turnstiles_df["C/A"] == "A002") & 
        (turnstiles_df["UNIT"] == "R051") & 
        (turnstiles_df["SCP"] == "02-00-00") & 
        (turnstiles_df["STATION"] == "59 ST"))
turnstiles_df[mask].head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/03/2017  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/03/2017  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/03/2017  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/03/2017  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/03/2017  16:00:00
#
#       DESC  ENTRIES    EXITS
# 0  REGULAR  6203652  2101226
# 1  REGULAR  6203674  2101230
# 2  REGULAR  6203688  2101260
# 3  REGULAR  6203769  2101343
# 4  REGULAR  6203987  2101401

# %%
# Convert date and time fields into a single datetime column
turnstiles_df["DATE_TIME"] = pd.to_datetime(turnstiles_df.DATE + " " +turnstiles_df.TIME, format="%m/%d/%Y %H:%M:%S")

# %%
turnstiles_df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/03/2017  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/03/2017  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/03/2017  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/03/2017  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  06/03/2017  16:00:00
#
#       DESC  ENTRIES    EXITS           DATE_TIME
# 0  REGULAR  6203652  2101226 2017-06-03 00:00:00
# 1  REGULAR  6203674  2101230 2017-06-03 04:00:00
# 2  REGULAR  6203688  2101260 2017-06-03 08:00:00
# 3  REGULAR  6203769  2101343 2017-06-03 12:00:00
# 4  REGULAR  6203987  2101401 2017-06-03 16:00:00

# %%
# Sanity Check to verify that "C/A", "UNIT", "SCP", "STATION", "DATE_TIME" is unique
(turnstiles_df
 .groupby(["C/A", "UNIT", "SCP", "STATION", "DATE_TIME"])
 .ENTRIES.count()
 .reset_index()
 .sort_values("ENTRIES", ascending=False)).head(5)
# Out:
#          C/A  UNIT       SCP          STATION           DATE_TIME  ENTRIES
# 713692  R518  R261  00-03-02  40 ST LOWERY ST 2017-06-05 08:00:00        2
# 526442  R147  R033  04-00-02   TIMES SQ-42 ST 2017-06-24 00:00:00        1
# 526443  R147  R033  04-00-02   TIMES SQ-42 ST 2017-06-24 04:00:00        1
# 526444  R147  R033  04-00-02   TIMES SQ-42 ST 2017-06-24 08:00:00        1
# 526445  R147  R033  04-00-02   TIMES SQ-42 ST 2017-06-24 12:00:00        1

# %%
# On 9/16, we seem to have two entries for same time.  Let's take a look
mask = ((turnstiles_df["C/A"] == "R518") & 
(turnstiles_df["UNIT"] == "R261") & 
(turnstiles_df["SCP"] == "00-03-02") & 
(turnstiles_df["STATION"] == "40 ST LOWERY ST") &
# get datetime properties ~ .dt
(turnstiles_df["DATE_TIME"].dt.date == datetime.datetime(2017, 6, 5, 8, 0, 0).date()))
turnstiles_df[mask].head()
# Out:
#          C/A  UNIT       SCP          STATION LINENAME DIVISION        DATE  \
# 178843  R518  R261  00-03-02  40 ST LOWERY ST        7      IRT  06/05/2017
# 178844  R518  R261  00-03-02  40 ST LOWERY ST        7      IRT  06/05/2017
# 178845  R518  R261  00-03-02  40 ST LOWERY ST        7      IRT  06/05/2017
# 178846  R518  R261  00-03-02  40 ST LOWERY ST        7      IRT  06/05/2017
# 178847  R518  R261  00-03-02  40 ST LOWERY ST        7      IRT  06/05/2017
#
#             TIME        DESC   ENTRIES    EXITS           DATE_TIME
# 178843  00:00:00     REGULAR  18778202  7453672 2017-06-05 00:00:00
# 178844  04:00:00     REGULAR  18778218  7453692 2017-06-05 04:00:00
# 178845  08:00:00     REGULAR  18778966  7453831 2017-06-05 08:00:00
# 178846  08:00:00  RECOVR AUD  18778965  7453831 2017-06-05 08:00:00
# 178847  12:00:00     REGULAR  18780198  7454059 2017-06-05 12:00:00

# %% [markdown]
# * Looks to be a incorrect AUD entry.  May be we should just select the Regular One.

# %%
turnstiles_df.DESC.value_counts()
# Out:
# REGULAR       786980
# RECOVR AUD      2697
# Name: DESC, dtype: int64

# %% [markdown]
# * Since we are only interested in Entries, we might be OK.

# %%
turnstiles_df.sort_values(["C/A", "UNIT", "SCP", "STATION", "DATE_TIME"], inplace=True, ascending=False)
# Get rid of the duplicate entry
turnstiles_df.drop_duplicates(subset=["C/A", "UNIT", "SCP", "STATION", "DATE_TIME"], inplace=True)

# %%
# Sanity Check to verify that "C/A", "UNIT", "SCP", "STATION", "DATE_TIME" is unique
(turnstiles_df
 .groupby(["C/A", "UNIT", "SCP", "STATION", "DATE_TIME"])
 .ENTRIES.count()
 .reset_index()
 .sort_values("ENTRIES", ascending=False)).head(5)
# Out:
#          C/A  UNIT       SCP         STATION           DATE_TIME  ENTRIES
# 0       A002  R051  02-00-00           59 ST 2017-06-03 00:00:00        1
# 526514  R147  R033  04-00-03  TIMES SQ-42 ST 2017-06-07 20:00:00        1
# 526444  R147  R033  04-00-02  TIMES SQ-42 ST 2017-06-24 08:00:00        1
# 526445  R147  R033  04-00-02  TIMES SQ-42 ST 2017-06-24 12:00:00        1
# 526446  R147  R033  04-00-02  TIMES SQ-42 ST 2017-06-24 16:00:00        1

# %% [markdown]
# * No more duplicate Entries

# %% [markdown]
# #### Exercise 1.3
#
# - **These counts are for every n hours. (What is n?) We want total daily
#   entries.**
#
# Now make it that we again have the same keys, but now we have a single
# value for a single day, which is the total number of passengers that
# entered through this turnstile on this day.

# %%
# Coalesce duplicate LINENAMEs that were out of order (eg. 'CBA' becomes 'ABC')
def sort_linename(linename):
    return ''.join(sorted(linename))
turnstiles_df['LINENAME'] = turnstiles_df.LINENAME.apply(sort_linename)

# %%
# returns a series
turnstiles_hourly = turnstiles_df.groupby\
                (["C/A", "UNIT", "SCP", "STATION", "LINENAME", "DATE", "TIME", "DATE_TIME"])\
                ['ENTRIES','EXITS'].first().reset_index()

# %%
# define three new columns using 
turnstiles_hourly[["PREV_DATE", "PREV_ENTRIES", "PREV_EXITS"]] = (turnstiles_hourly
                                                       .groupby(["C/A", "UNIT", "SCP", "STATION"])["DATE_TIME", "ENTRIES", "EXITS"]
                                                       .transform(lambda grp: grp.shift(1)))

# %%
turnstiles_hourly.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  456NQRW  06/03/2017  00:00:00
# 1  A002  R051  02-00-00   59 ST  456NQRW  06/03/2017  04:00:00
# 2  A002  R051  02-00-00   59 ST  456NQRW  06/03/2017  08:00:00
# 3  A002  R051  02-00-00   59 ST  456NQRW  06/03/2017  12:00:00
# 4  A002  R051  02-00-00   59 ST  456NQRW  06/03/2017  16:00:00
#
#             DATE_TIME  ENTRIES    EXITS           PREV_DATE  PREV_ENTRIES  \
# 0 2017-06-03 00:00:00  6203652  2101226                 NaT           NaN
# 1 2017-06-03 04:00:00  6203674  2101230 2017-06-03 00:00:00     6203652.0
# 2 2017-06-03 08:00:00  6203688  2101260 2017-06-03 04:00:00     6203674.0
# 3 2017-06-03 12:00:00  6203769  2101343 2017-06-03 08:00:00     6203688.0
# 4 2017-06-03 16:00:00  6203987  2101401 2017-06-03 12:00:00     6203769.0
#
#    PREV_EXITS
# 0         NaN
# 1   2101226.0
# 2   2101230.0
# 3   2101260.0
# 4   2101343.0

# %%
# Drop rows for first date
turnstiles_hourly.dropna(subset=["PREV_DATE"], axis=0, inplace=True)

# %%
turnstiles_hourly.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME        DATE      TIME  \
# 1  A002  R051  02-00-00   59 ST  456NQRW  06/03/2017  04:00:00
# 2  A002  R051  02-00-00   59 ST  456NQRW  06/03/2017  08:00:00
# 3  A002  R051  02-00-00   59 ST  456NQRW  06/03/2017  12:00:00
# 4  A002  R051  02-00-00   59 ST  456NQRW  06/03/2017  16:00:00
# 5  A002  R051  02-00-00   59 ST  456NQRW  06/03/2017  20:00:00
#
#             DATE_TIME  ENTRIES    EXITS           PREV_DATE  PREV_ENTRIES  \
# 1 2017-06-03 04:00:00  6203674  2101230 2017-06-03 00:00:00     6203652.0
# 2 2017-06-03 08:00:00  6203688  2101260 2017-06-03 04:00:00     6203674.0
# 3 2017-06-03 12:00:00  6203769  2101343 2017-06-03 08:00:00     6203688.0
# 4 2017-06-03 16:00:00  6203987  2101401 2017-06-03 12:00:00     6203769.0
# 5 2017-06-03 20:00:00  6204271  2101450 2017-06-03 16:00:00     6203987.0
#
#    PREV_EXITS
# 1   2101226.0
# 2   2101230.0
# 3   2101260.0
# 4   2101343.0
# 5   2101401.0

# %%
# sanity check : when are previous entries greater than current ? 
turnstiles_hourly[turnstiles_hourly["ENTRIES"] < turnstiles_hourly["PREV_ENTRIES"]].head()
# Out:
#        C/A  UNIT       SCP     STATION LINENAME        DATE      TIME  \
# 2447  A006  R079  00-00-02  5 AV/59 ST     NQRW  06/18/2017  14:00:00
# 5720  A011  R080  01-00-00  57 ST-7 AV     NQRW  06/03/2017  04:00:00
# 5721  A011  R080  01-00-00  57 ST-7 AV     NQRW  06/03/2017  08:00:00
# 5722  A011  R080  01-00-00  57 ST-7 AV     NQRW  06/03/2017  12:00:00
# 5723  A011  R080  01-00-00  57 ST-7 AV     NQRW  06/03/2017  16:00:00
#
#                DATE_TIME    ENTRIES      EXITS           PREV_DATE  \
# 2447 2017-06-18 14:00:00    5439480   16169264 2017-06-18 10:00:00
# 5720 2017-06-03 04:00:00  886917698  492571284 2017-06-03 00:00:00
# 5721 2017-06-03 08:00:00  886917638  492570955 2017-06-03 04:00:00
# 5722 2017-06-03 12:00:00  886917354  492570248 2017-06-03 08:00:00
# 5723 2017-06-03 16:00:00  886916793  492569519 2017-06-03 12:00:00
#
#       PREV_ENTRIES   PREV_EXITS
# 2447     7807254.0    3433327.0
# 5720   886917876.0  492571326.0
# 5721   886917698.0  492571284.0
# 5722   886917638.0  492570955.0
# 5723   886917354.0  492570248.0

# %%
# What's the deal with counter going in reverse ? 
# investigate this with turnstiles_df
mask = ((turnstiles_df["C/A"] == "A011") & 
(turnstiles_df["UNIT"] == "R080") & 
(turnstiles_df["SCP"] == "01-00-00") & 
(turnstiles_df["STATION"] == "57 ST-7 AV") &
(turnstiles_df["DATE_TIME"].dt.date == datetime.datetime(2017, 6, 3).date()))
turnstiles_df[mask].head()

# entries going up, datetime going down
# Out:
#        C/A  UNIT       SCP     STATION LINENAME DIVISION        DATE  \
# 1433  A011  R080  01-00-00  57 ST-7 AV     NQRW      BMT  06/03/2017
# 1432  A011  R080  01-00-00  57 ST-7 AV     NQRW      BMT  06/03/2017
# 1431  A011  R080  01-00-00  57 ST-7 AV     NQRW      BMT  06/03/2017
# 1430  A011  R080  01-00-00  57 ST-7 AV     NQRW      BMT  06/03/2017
# 1429  A011  R080  01-00-00  57 ST-7 AV     NQRW      BMT  06/03/2017
#
#           TIME     DESC    ENTRIES      EXITS           DATE_TIME
# 1433  20:00:00  REGULAR  886916139  492568911 2017-06-03 20:00:00
# 1432  16:00:00  REGULAR  886916793  492569519 2017-06-03 16:00:00
# 1431  12:00:00  REGULAR  886917354  492570248 2017-06-03 12:00:00
# 1430  08:00:00  REGULAR  886917638  492570955 2017-06-03 08:00:00
# 1429  04:00:00  REGULAR  886917698  492571284 2017-06-03 04:00:00

# %% [markdown]
# * Counter working in Reverse??? - WHHHAT

# %%
# Let's see how many stations have this problem

(turnstiles_hourly[turnstiles_hourly["ENTRIES"] < turnstiles_hourly["PREV_ENTRIES"]]
    .groupby(["C/A", "UNIT", "SCP", "STATION"])
     .size())
# Out:
# C/A    UNIT  SCP       STATION
# A006   R079  00-00-02  5 AV/59 ST           1
# A011   R080  01-00-00  57 ST-7 AV         170
# A025   R023  01-03-01  34 ST-HERALD SQ    167
#              01-03-02  34 ST-HERALD SQ    165
# A043   R462  00-06-00  CANAL ST             2
# A049   R088  02-05-00  CORTLANDT ST        40
# A060   R001  00-00-02  WHITEHALL S-FRY      1
#              00-00-04  WHITEHALL S-FRY      1
#              00-00-06  WHITEHALL S-FRY      1
# A066   R118  00-00-00  CANAL ST           167
# B020   R263  00-05-00  AVENUE H             1
# B025   R150  00-00-01  AVENUE U             1
# C021   R212  00-00-02  59 ST              178
# E011   R371  00-06-01  79 ST                1
# H003   R163  01-00-02  6 AV               166
# H009   R235  00-06-05  BEDFORD AV           1
# H023   R236  00-06-00  DEKALB AV          167
# J034   R007  00-00-02  104 ST             124
# JFK01  R535  00-00-02  HOWARD BCH JFK       1
# JFK02  R535  01-00-03  HOWARD BCH JFK       1
# JFK03  R536  00-03-00  JFK JAMAICA CT1      2
#              00-03-02  JFK JAMAICA CT1      1
# K026   R100  00-00-01  METROPOLITAN AV    129
# N011   R126  01-05-00  175 ST               1
# N023   R332  01-00-01  135 ST               1
# N043   R186  00-00-00  86 ST                1
# N062   R011  01-00-00  42 ST-PORT AUTH      1
#              01-00-01  42 ST-PORT AUTH      1
#              01-00-02  42 ST-PORT AUTH      1
#              01-03-00  42 ST-PORT AUTH      1
#                                          ...
# R165   R167  01-00-00  86 ST                3
#              01-00-01  86 ST                1
#              01-00-02  86 ST                1
#              01-00-04  86 ST                2
# R169   R168  01-00-04  96 ST                1
# R204   R043  02-03-02  WALL ST              1
# R205A  R014  04-02-01  FULTON ST            1
#              04-02-02  FULTON ST            1
#              04-02-03  FULTON ST            1
# R210   R044  00-03-04  BROOKLYN BRIDGE    170
# R227   R131  00-00-00  23 ST              168
# R240   R047  00-00-01  GRD CNTRL-42 ST      1
# R241A  R048  00-00-00  GRD CNTRL-42 ST    175
# R245   R051  00-00-00  59 ST              167
# R246   R177  00-00-02  68ST-HUNTER CO       1
# R252   R180  00-03-00  103 ST               2
# R258   R132  00-00-03  125 ST             168
# R261   R205  00-00-02  149/GRAND CONC       1
# R304   R206  00-00-00  125 ST             168
# R305   R206  01-00-02  125 ST             166
# R310   R053  01-00-02  3 AV-149 ST        168
# R322   R386  00-00-02  174 ST             170
# R325   R388  00-00-00  E 180 ST             1
#              00-00-02  E 180 ST             1
#              00-00-03  E 180 ST             1
# R413   R325  00-05-01  WHITLOCK AV          1
# R416   R245  00-00-00  ST LAWRENCE AV       1
# R622   R123  00-00-00  FRANKLIN AV        170
# R646   R110  01-00-01  FLATBUSH AV-B.C    167
# R730   R431  00-00-04  EASTCHSTER/DYRE    143
# Length: 150, dtype: int64

# %%
def get_counts(row, max_counter, col_name):
    counter = row[col_name] - row["PREV_"+col_name]
    if counter < 0:
        # May be counter is reversed?
        counter = -counter
    if counter > max_counter:
#         print(row[col_name], row["PREV_"+col_name])
        counter = min(row[col_name], row["PREV_"+col_name])
    if counter > max_counter:
        # Check it again to make sure we are not giving a counter that's too big
        return 0
    return counter

# %%
# If counter is > 1Million, then the counter might have been reset.  
# Just set it to zero as different counters have different cycle limits
turnstiles_hourly["HOURLY_ENTRIES"] = turnstiles_hourly.apply(get_counts, col_name='ENTRIES', axis=1, max_counter=10000)
turnstiles_hourly["HOURLY_EXITS"] = turnstiles_hourly.apply(get_counts, col_name='EXITS', axis=1, max_counter=10000)

# %%
turnstiles_hourly['TOTAL_TRAFFIC'] = turnstiles_hourly.HOURLY_ENTRIES + turnstiles_hourly.HOURLY_EXITS
turnstiles_hourly['DT_DIFF'] = turnstiles_hourly.DATE_TIME - turnstiles_hourly.PREV_DATE
turnstiles_hourly['DOW'] = turnstiles_hourly['DATE_TIME'].dt.weekday_name

# Create WEEKEND field
weekend_indices = turnstiles_hourly[(turnstiles_hourly.DOW == 'Saturday') | (turnstiles_hourly.DOW == 'Sunday')].index
weekday_indices = turnstiles_hourly[(turnstiles_hourly.DOW != 'Saturday') & (turnstiles_hourly.DOW != 'Sunday')].index
turnstiles_hourly.loc[weekend_indices, 'WEEKEND'] = 'Weekend'
turnstiles_hourly.loc[weekday_indices, 'WEEKEND'] = 'Weekday'

# %%
# Turn TIME from string to timestamp
turnstiles_hourly['TIME'] = turnstiles_hourly['TIME']. \
    apply(lambda x: datetime.datetime.strptime(x, '%H:%M:%S').time())

# %%
AM_indices = turnstiles_hourly[turnstiles_hourly.TIME < datetime.time(14,0)].index
PM_indices = turnstiles_hourly[turnstiles_hourly.TIME >= datetime.time(14,0)].index
turnstiles_hourly.loc[AM_indices, 'TOD'] = 'AM'
turnstiles_hourly.loc[PM_indices, 'TOD'] = 'PM'

# %%
turnstiles_hourly.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME        DATE      TIME  \
# 1  A002  R051  02-00-00   59 ST  456NQRW  06/03/2017  04:00:00
# 2  A002  R051  02-00-00   59 ST  456NQRW  06/03/2017  08:00:00
# 3  A002  R051  02-00-00   59 ST  456NQRW  06/03/2017  12:00:00
# 4  A002  R051  02-00-00   59 ST  456NQRW  06/03/2017  16:00:00
# 5  A002  R051  02-00-00   59 ST  456NQRW  06/03/2017  20:00:00
#
#             DATE_TIME  ENTRIES    EXITS           PREV_DATE  PREV_ENTRIES  \
# 1 2017-06-03 04:00:00  6203674  2101230 2017-06-03 00:00:00     6203652.0
# 2 2017-06-03 08:00:00  6203688  2101260 2017-06-03 04:00:00     6203674.0
# 3 2017-06-03 12:00:00  6203769  2101343 2017-06-03 08:00:00     6203688.0
# 4 2017-06-03 16:00:00  6203987  2101401 2017-06-03 12:00:00     6203769.0
# 5 2017-06-03 20:00:00  6204271  2101450 2017-06-03 16:00:00     6203987.0
#
#    PREV_EXITS  HOURLY_ENTRIES  HOURLY_EXITS  TOTAL_TRAFFIC  DT_DIFF       DOW  \
# 1   2101226.0            22.0           4.0           26.0 04:00:00  Saturday
# 2   2101230.0            14.0          30.0           44.0 04:00:00  Saturday
# 3   2101260.0            81.0          83.0          164.0 04:00:00  Saturday
# 4   2101343.0           218.0          58.0          276.0 04:00:00  Saturday
# 5   2101401.0           284.0          49.0          333.0 04:00:00  Saturday
#
#    WEEKEND TOD
# 1  Weekend  AM
# 2  Weekend  AM
# 3  Weekend  AM
# 4  Weekend  PM
# 5  Weekend  PM

# %%
# Plots for top trafficked stations by time period
for day in ['Weekday']:
    for tod in ['AM','PM']:
        mask = ((turnstiles_hourly.WEEKEND == day) 
            & (turnstiles_hourly.TOD == tod)
        #    & (turnstiles_hourly.DT_DIFF == pd.Timedelta('4 hours'))
               )
        df = turnstiles_hourly[mask].groupby(['STATION','LINENAME'], as_index=False).agg(
            {'HOURLY_EXITS': 'sum','HOURLY_ENTRIES': 'sum','TOTAL_TRAFFIC': 'sum'})
        df = df.sort_values(by='TOTAL_TRAFFIC', ascending=False).head(10)
        df = df.iloc[::-1]
        df.drop('TOTAL_TRAFFIC', axis=1, inplace=True)
        df.rename(columns={'HOURLY_EXITS':'EXITS','HOURLY_ENTRIES': 'ENTRIES'}, inplace=True)
        df.plot(kind='barh', title=day + tod, x=df.STATION + ": " + df.LINENAME, xticks=[0, 500000, 1000000, 1500000, 2000000])
#         print(day, tod, df, '\n')

# %%
# Which Control Areas (C/A) get the most traffic?
station = '34 ST-PENN STA'
df = turnstiles_hourly[turnstiles_hourly.STATION==station]
df.groupby(['C/A']).TOTAL_TRAFFIC.sum().sort_values().plot(kind='barh', title=station)

# %%
grouped_df = turnstiles_hourly.groupby(['STATION','LINENAME', 'WEEKEND',
                            pd.Grouper(key='DATE_TIME', freq='4H')], 
                            )['TOTAL_TRAFFIC'].sum().reset_index()
grouped_df['TIME'] = grouped_df.DATE_TIME.apply(lambda x: x.hour)

# %% [markdown]
# ## Time Series by 4hr blocks

# %%
stations = ['GRD CNTRL-42 ST4567S', 
#             '59 ST COLUMBUS1ABCD', 
#     'FOREST HILLS 71EFMR', 
#             '42 ST-PORT AUTH1237ACENQRSW', 
            '34 ST-HERALD SQBDFMNQRW',
            '14 ST-UNION SQ456LNQRW']

mask = (((grouped_df['STATION'] + grouped_df['LINENAME']).isin(stations)) &
        (grouped_df['WEEKEND'] == 'Weekday'))

df = grouped_df[mask]
df.loc[df['TIME']==0, 'TIME'] = 24
df.head()
# Out:
# /Users/macbook/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#              STATION  LINENAME  WEEKEND           DATE_TIME  TOTAL_TRAFFIC  \
# 4328  14 ST-UNION SQ  456LNQRW  Weekday 2017-06-05 00:00:00        11969.0
# 4329  14 ST-UNION SQ  456LNQRW  Weekday 2017-06-05 04:00:00         1223.0
# 4330  14 ST-UNION SQ  456LNQRW  Weekday 2017-06-05 08:00:00        29212.0
# 4331  14 ST-UNION SQ  456LNQRW  Weekday 2017-06-05 12:00:00        39177.0
# 4332  14 ST-UNION SQ  456LNQRW  Weekday 2017-06-05 16:00:00        48070.0
#
#       TIME
# 4328    24
# 4329     4
# 4330     8
# 4331    12
# 4332    16

# %%
fig.set_size_inches(10,6)
# Draw a nested barplot to show survival for class and sex
g = sns.factorplot(x="TIME", y="TOTAL_TRAFFIC", data=df,
                   size=4, #kind="bar",
#                    palette=sns.diverging_palette(220, 220, n=20),
                   aspect = 3,
                   hue = 'STATION'
            )
g.despine(left=True)
g.set_xticklabels(rotation=0, labels=['12am-4am','4am-8am','8am-12pm','12pm-4pm','4pm-8pm','8pm-12am'])
g.set(title='WEEKDAYS')

g.set_ylabels("Total Traffic")

# %%
fig.set_size_inches(10,6)
# Draw a nested barplot to show survival for class and sex
g = sns.factorplot(x="TIME", y="TOTAL_TRAFFIC", data=df,
                   size=4, kind="bar",
#                    palette=sns.diverging_palette(220, 220, n=20),
                   aspect = 3,
                   hue = 'STATION'
            )
g.despine(left=True)
g.set_xticklabels(rotation=0, labels=['12am-4am','4am-8am','8am-12pm','12pm-4pm','4pm-8pm','8pm-12am'])
g.set(title='WEEKDAY')

g.set_ylabels("Total Traffic")

# %% [markdown]
# ### Match stations to location?

# %%
entrances_df = pd.read_csv('http://web.mta.info/developers/data/nyct/subway/StationEntrances.csv')

lat_long = entrances_df.groupby(['Station_Name'])['Station_Latitude','Station_Longitude'].first()
lat_long.reset_index(inplace=True)

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
stations = turnstiles_df.STATION.unique().tolist()

lat_long['STATION'] = lat_long.Station_Name.apply(lambda x:
                                                  process.extractOne(x, stations, scorer=fuzz.token_sort_ratio)[0])
lat_long['Match Score'] = lat_long.Station_Name.apply(lambda x:
                                                  process.extractOne(x, stations, scorer=fuzz.token_sort_ratio)[1])

# %%
lat_long.head(10)
# Out:
#                    Station_Name  Station_Latitude  Station_Longitude  \
# 0                      103rd St         40.796092         -73.961454
# 1             104th St-102nd St         40.695178         -73.844330
# 2            104th St-Oxford Av         40.681711         -73.837683
# 3                      110th St         40.795020         -73.944250
# 4   110th St-Central Park North         40.799075         -73.951822
# 5                      111th St         40.697418         -73.836345
# 6         111th St-Greenwood Av         40.684331         -73.832163
# 7                      116th St         40.805085         -73.954882
# 8  116th St-Columbia University         40.807722         -73.964110
# 9                      121st St         40.700492         -73.828294
#
#            STATION  Match Score
# 0           103 ST           86
# 1      14TH STREET           57
# 2       FOREST AVE           57
# 3           110 ST           86
# 4  CENTRAL PK N110           57
# 5           111 ST           86
# 6    GREENPOINT AV           59
# 7           116 ST           86
# 8  116 ST-COLUMBIA           70
# 9           121 ST           86

# %% [markdown]
# ### Add zip codes

# %%
# Add zip codes
from geopy.geocoders import Nominatim
geolocator = Nominatim()

# See an example of how this works
location = geolocator.reverse("40.697418, -73.836345")
print(location.address)
print(location.raw['address'])
# Out:
# 112-02, Jamaica Avenue, Brooklyn Manor, Queens County, NYC, New York, 11418, United States of America
# {'house_number': '112-02', 'road': 'Jamaica Avenue', 'neighbourhood': 'Brooklyn Manor', 'county': 'Queens County', 'city': 'NYC', 'state': 'New York', 'postcode': '11418', 'country': 'United States of America', 'country_code': 'us'}

# %%
from geopy.geocoders import Nominatim

# %%
def find_address(lat, long):
    geolocator = Nominatim()
    latlong = str(lat) + ', ' + str(long)
    location = geolocator.reverse(latlong)
    return location.raw['address']

# %%
lat_long_list = []

# %%
# # Go by increments up to index=354, since bulk call times out
# for i in range(50,51):    
#     address = find_address(lat_long.Station_Latitude[i], lat_long.Station_Longitude[i])
#     lat_long_list.append((i, lat_long.loc[i,'Station_Name'], address))

# Bulk call that times out
lat_long['zipcode'] = lat_long.apply(lambda row: find_address(
                row['Station_Latitude'], row['Station_Longitude'])['postcode'], axis=1)

# %%
print(len(lat_long_list))
lat_long_list[353]
# Out:
# 354
# (354,
#  'Zerega Av',
#  {'city': 'NYC',
#   'country': 'United States of America',
#   'country_code': 'us',
#   'county': 'Bronx County',
#   'house_number': '2359',
#   'neighbourhood': 'Unionport',
#   'postcode': '10462',
#   'road': 'Westchester Avenue',
#   'state': 'New York',
#   'suburb': 'Bronx'})

# %%
# Add address field to lat_long
lat_long_list.sort(key=lambda x: x[0])
lat_long['address'] = lat_long_list

# %%
lat_long.head()
# Out:
#                   Station_Name  Station_Latitude  Station_Longitude  \
# 0                     103rd St         40.796092         -73.961454
# 1            104th St-102nd St         40.695178         -73.844330
# 2           104th St-Oxford Av         40.681711         -73.837683
# 3                     110th St         40.795020         -73.944250
# 4  110th St-Central Park North         40.799075         -73.951822
#
#            STATION  Match Score zipcode  \
# 0           103 ST           86   10025
# 1      14TH STREET           57   11418
# 2       FOREST AVE           57   11417
# 3           110 ST           86   10029
# 4  CENTRAL PK N110           57   10026
#
#                                              address     suburb  \
# 0  (0, 103rd St, {'house_number': '435', 'road': ...  Manhattan
# 1  (1, 104th St-102nd St, {'house_number': '102-2...        NaN
# 2  (2, 104th St-Oxford Av, {'house_number': '103-...        NaN
# 3  (3, 110th St, {'house_number': '1779', 'road':...  Manhattan
# 4  (4, 110th St-Central Park North, {'house_numbe...  Manhattan
#
#      neighborhood
# 0    Central Park
# 1  Brooklyn Manor
# 2     Morris Park
# 3             NaN
# 4          Harlem

# %%
# pull fields out of address
lat_long['zipcode'] = lat_long.address.apply(lambda x: x[2]['postcode'])
lat_long['suburb'] = lat_long.address.apply(lambda x: x[2].get('suburb', np.NaN))
lat_long['neighborhood'] = lat_long.address.apply(lambda x: x[2].get('neighbourhood', np.NaN))

# Shorten zip codes
lat_long['short_zip'] = lat_long.zipcode.apply(lambda x: x[:5])

# %%
lat_long.to_csv('lat_long.csv')

# %%
# Top zip codes for Females with Science jobs
good_zips = [10016, 10023, 10024, 10025, 11211, 11215, 11375]
good_zips = [str(x) for x in good_zips]

# %%
top_stations = lat_long[lat_long.short_zip.apply(lambda x: x in good_zips)]

# %%
top_stations[['STATION','short_zip','neighborhood']].sort_values(by='short_zip')
# Out:
#              STATION short_zip     neighborhood
# 57             33 ST     10016      Murray Hill
# 76    59 ST COLUMBUS     10023  Upper West Side
# 87             72 ST     10023  Upper West Side
# 0             103 ST     10025     Central Park
# 268         MARCY AV     11211     Williamsburg
# 230         HEWES ST     11211     Williamsburg
# 133       BEDFORD AV     11211     Williamsburg
# 224         GRAND ST     11211     Williamsburg
# 219        GRAHAM AV     11211     Williamsburg
# 305   15 ST-PROSPECT     11215  Windsor Terrace
# 303      PROSPECT AV     11215       Park Slope
# 334         UNION ST     11215          Gowanus
# 103       9TH STREET     11215       Park Slope
# 69              7 AV     11215          Gowanus
# 320       SMITH-9 ST     11215  Carroll Gardens
# 248      KEW GARDENS     11375     Forest Hills
# 88             75 AV     11375     Forest Hills
# 83             67 AV     11375     Forest Hills
# 210  FOREST HILLS 71     11375     Forest Hills

# %%
my_stations
# Out:
# [('HEWES ST', 'IM'),
#  ('75 AV', 'EF'),
#  ('103 ST', 'BC'),
#  ('SMITH-9 ST', 'FG'),
#  ('UNION ST', 'R'),
#  ('15 ST-PROSPECT', 'FG'),
#  ('67 AV', 'MR'),
#  ('GRAND ST', 'L'),
#  ('72 ST', 'BC'),
#  ('GRAHAM AV', 'L'),
#  ('7AV', 'FG'),
#  ('103 ST', '1'),
#  ('MARCY AV', 'IMZ'),
#  ('FOREST HILLS 71', 'EFMR'),
#  ('KEW GARDENS', 'EF'),
#  ('33 ST', '6'),
#  ('BEDFORD AV', 'L'),
#  ('72 ST', '123'),
#  ('59 ST COLUMBUS', '1ABCD')]

# %%
td = turnstiles_hourly.set_index(['STATION','LINENAME'],drop=False)
td
# Out:
#                           C/A  UNIT       SCP        STATION LINENAME  \
# STATION       LINENAME
# 59 ST         456NQRW    A002  R051  02-00-00          59 ST  456NQRW
#               456NQRW    A002  R051  02-00-00          59 ST  456NQRW
#               456NQRW    A002  R051  02-00-00          59 ST  456NQRW
#               456NQRW    A002  R051  02-00-00          59 ST  456NQRW
#               456NQRW    A002  R051  02-00-00          59 ST  456NQRW
#               456NQRW    A002  R051  02-00-00          59 ST  456NQRW
#               456NQRW    A002  R051  02-00-00          59 ST  456NQRW
#               456NQRW    A002  R051  02-00-00          59 ST  456NQRW
#               456NQRW    A002  R051  02-00-00          59 ST  456NQRW
#               456NQRW    A002  R051  02-00-00          59 ST  456NQRW
#               456NQRW    A002  R051  02-00-00          59 ST  456NQRW
#               456NQRW    A002  R051  02-00-00          59 ST  456NQRW
#               456NQRW    A002  R051  02-00-00          59 ST  456NQRW
#               456NQRW    A002  R051  02-00-00          59 ST  456NQRW
#               456NQRW    A002  R051  02-00-00          59 ST  456NQRW
#               456NQRW    A002  R051  02-00-00          59 ST  456NQRW
#               456NQRW    A002  R051  02-00-00          59 ST  456NQRW
#               456NQRW    A002  R051  02-00-00          59 ST  456NQRW
#               456NQRW    A002  R051  02-00-00          59 ST  456NQRW
#               456NQRW    A002  R051  02-00-00          59 ST  456NQRW
#               456NQRW    A002  R051  02-00-00          59 ST  456NQRW
#               456NQRW    A002  R051  02-00-00          59 ST  456NQRW
#               456NQRW    A002  R051  02-00-00          59 ST  456NQRW
#               456NQRW    A002  R051  02-00-00          59 ST  456NQRW
#               456NQRW    A002  R051  02-00-00          59 ST  456NQRW
#               456NQRW    A002  R051  02-00-00          59 ST  456NQRW
#               456NQRW    A002  R051  02-00-00          59 ST  456NQRW
#               456NQRW    A002  R051  02-00-00          59 ST  456NQRW
#               456NQRW    A002  R051  02-00-00          59 ST  456NQRW
#               456NQRW    A002  R051  02-00-00          59 ST  456NQRW
# ...                       ...   ...       ...            ...      ...
# RIT-ROOSEVELT R         TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#               R         TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#               R         TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#               R         TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#               R         TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#               R         TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#               R         TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#               R         TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#               R         TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#               R         TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#               R         TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#               R         TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#               R         TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#               R         TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#               R         TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#               R         TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#               R         TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#               R         TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#               R         TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#               R         TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#               R         TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#               R         TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#               R         TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#               R         TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#               R         TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#               R         TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#               R         TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#               R         TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#               R         TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#               R         TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#
#                               DATE      TIME           DATE_TIME  ENTRIES  \
# STATION       LINENAME
# 59 ST         456NQRW   06/03/2017  04:00:00 2017-06-03 04:00:00  6203674
#               456NQRW   06/03/2017  08:00:00 2017-06-03 08:00:00  6203688
#               456NQRW   06/03/2017  12:00:00 2017-06-03 12:00:00  6203769
#               456NQRW   06/03/2017  16:00:00 2017-06-03 16:00:00  6203987
#               456NQRW   06/03/2017  20:00:00 2017-06-03 20:00:00  6204271
#               456NQRW   06/04/2017  00:00:00 2017-06-04 00:00:00  6204416
#               456NQRW   06/04/2017  04:00:00 2017-06-04 04:00:00  6204432
#               456NQRW   06/04/2017  08:00:00 2017-06-04 08:00:00  6204447
#               456NQRW   06/04/2017  12:00:00 2017-06-04 12:00:00  6204517
#               456NQRW   06/04/2017  16:00:00 2017-06-04 16:00:00  6204723
#               456NQRW   06/04/2017  20:00:00 2017-06-04 20:00:00  6204890
#               456NQRW   06/05/2017  00:00:00 2017-06-05 00:00:00  6204981
#               456NQRW   06/05/2017  04:00:00 2017-06-05 04:00:00  6204994
#               456NQRW   06/05/2017  08:00:00 2017-06-05 08:00:00  6205038
#               456NQRW   06/05/2017  12:00:00 2017-06-05 12:00:00  6205198
#               456NQRW   06/05/2017  16:00:00 2017-06-05 16:00:00  6205483
#               456NQRW   06/05/2017  20:00:00 2017-06-05 20:00:00  6206143
#               456NQRW   06/06/2017  00:00:00 2017-06-06 00:00:00  6206340
#               456NQRW   06/06/2017  04:00:00 2017-06-06 04:00:00  6206360
#               456NQRW   06/06/2017  08:00:00 2017-06-06 08:00:00  6206420
#               456NQRW   06/06/2017  12:00:00 2017-06-06 12:00:00  6206674
#               456NQRW   06/06/2017  16:00:00 2017-06-06 16:00:00  6207083
#               456NQRW   06/06/2017  20:00:00 2017-06-06 20:00:00  6207902
#               456NQRW   06/07/2017  00:00:00 2017-06-07 00:00:00  6208121
#               456NQRW   06/07/2017  04:00:00 2017-06-07 04:00:00  6208137
#               456NQRW   06/07/2017  08:00:00 2017-06-07 08:00:00  6208207
#               456NQRW   06/07/2017  12:00:00 2017-06-07 12:00:00  6208433
#               456NQRW   06/07/2017  16:00:00 2017-06-07 16:00:00  6208902
#               456NQRW   06/07/2017  20:00:00 2017-06-07 20:00:00  6210102
#               456NQRW   06/08/2017  00:00:00 2017-06-08 00:00:00  6210482
# ...                            ...       ...                 ...      ...
# RIT-ROOSEVELT R         06/26/2017  05:00:00 2017-06-26 05:00:00     5554
#               R         06/26/2017  09:00:00 2017-06-26 09:00:00     5554
#               R         06/26/2017  13:00:00 2017-06-26 13:00:00     5554
#               R         06/26/2017  17:00:00 2017-06-26 17:00:00     5554
#               R         06/26/2017  21:00:00 2017-06-26 21:00:00     5554
#               R         06/27/2017  01:00:00 2017-06-27 01:00:00     5554
#               R         06/27/2017  05:00:00 2017-06-27 05:00:00     5554
#               R         06/27/2017  09:00:00 2017-06-27 09:00:00     5554
#               R         06/27/2017  13:00:00 2017-06-27 13:00:00     5554
#               R         06/27/2017  17:00:00 2017-06-27 17:00:00     5554
#               R         06/27/2017  21:00:00 2017-06-27 21:00:00     5554
#               R         06/28/2017  01:00:00 2017-06-28 01:00:00     5554
#               R         06/28/2017  05:00:00 2017-06-28 05:00:00     5554
#               R         06/28/2017  09:00:00 2017-06-28 09:00:00     5554
#               R         06/28/2017  13:00:00 2017-06-28 13:00:00     5554
#               R         06/28/2017  17:00:00 2017-06-28 17:00:00     5554
#               R         06/28/2017  21:00:00 2017-06-28 21:00:00     5554
#               R         06/29/2017  01:00:00 2017-06-29 01:00:00     5554
#               R         06/29/2017  05:00:00 2017-06-29 05:00:00     5554
#               R         06/29/2017  09:00:00 2017-06-29 09:00:00     5554
#               R         06/29/2017  13:00:00 2017-06-29 13:00:00     5554
#               R         06/29/2017  17:00:00 2017-06-29 17:00:00     5554
#               R         06/29/2017  21:00:00 2017-06-29 21:00:00     5554
#               R         06/30/2017  01:00:00 2017-06-30 01:00:00     5554
#               R         06/30/2017  05:00:00 2017-06-30 05:00:00     5554
#               R         06/30/2017  07:17:19 2017-06-30 07:17:19     5554
#               R         06/30/2017  09:00:00 2017-06-30 09:00:00     5554
#               R         06/30/2017  13:00:00 2017-06-30 13:00:00     5554
#               R         06/30/2017  17:00:00 2017-06-30 17:00:00     5554
#               R         06/30/2017  21:00:00 2017-06-30 21:00:00     5554
#
#                           EXITS           PREV_DATE  PREV_ENTRIES  PREV_EXITS  \
# STATION       LINENAME
# 59 ST         456NQRW   2101230 2017-06-03 00:00:00     6203652.0   2101226.0
#               456NQRW   2101260 2017-06-03 04:00:00     6203674.0   2101230.0
#               456NQRW   2101343 2017-06-03 08:00:00     6203688.0   2101260.0
#               456NQRW   2101401 2017-06-03 12:00:00     6203769.0   2101343.0
#               456NQRW   2101450 2017-06-03 16:00:00     6203987.0   2101401.0
#               456NQRW   2101475 2017-06-03 20:00:00     6204271.0   2101450.0
#               456NQRW   2101480 2017-06-04 00:00:00     6204416.0   2101475.0
#               456NQRW   2101500 2017-06-04 04:00:00     6204432.0   2101480.0
#               456NQRW   2101569 2017-06-04 08:00:00     6204447.0   2101500.0
#               456NQRW   2101614 2017-06-04 12:00:00     6204517.0   2101569.0
#               456NQRW   2101646 2017-06-04 16:00:00     6204723.0   2101614.0
#               456NQRW   2101663 2017-06-04 20:00:00     6204890.0   2101646.0
#               456NQRW   2101665 2017-06-05 00:00:00     6204981.0   2101663.0
#               456NQRW   2101781 2017-06-05 04:00:00     6204994.0   2101665.0
#               456NQRW   2102059 2017-06-05 08:00:00     6205038.0   2101781.0
#               456NQRW   2102117 2017-06-05 12:00:00     6205198.0   2102059.0
#               456NQRW   2102238 2017-06-05 16:00:00     6205483.0   2102117.0
#               456NQRW   2102270 2017-06-05 20:00:00     6206143.0   2102238.0
#               456NQRW   2102270 2017-06-06 00:00:00     6206340.0   2102270.0
#               456NQRW   2102385 2017-06-06 04:00:00     6206360.0   2102270.0
#               456NQRW   2102638 2017-06-06 08:00:00     6206420.0   2102385.0
#               456NQRW   2102713 2017-06-06 12:00:00     6206674.0   2102638.0
#               456NQRW   2102781 2017-06-06 16:00:00     6207083.0   2102713.0
#               456NQRW   2102808 2017-06-06 20:00:00     6207902.0   2102781.0
#               456NQRW   2102810 2017-06-07 00:00:00     6208121.0   2102808.0
#               456NQRW   2102932 2017-06-07 04:00:00     6208137.0   2102810.0
#               456NQRW   2103186 2017-06-07 08:00:00     6208207.0   2102932.0
#               456NQRW   2103262 2017-06-07 12:00:00     6208433.0   2103186.0
#               456NQRW   2103320 2017-06-07 16:00:00     6208902.0   2103262.0
#               456NQRW   2103336 2017-06-07 20:00:00     6210102.0   2103320.0
# ...                         ...                 ...           ...         ...
# RIT-ROOSEVELT R             301 2017-06-26 01:00:00        5554.0       301.0
#               R             301 2017-06-26 05:00:00        5554.0       301.0
#               R             301 2017-06-26 09:00:00        5554.0       301.0
#               R             301 2017-06-26 13:00:00        5554.0       301.0
#               R             301 2017-06-26 17:00:00        5554.0       301.0
#               R             301 2017-06-26 21:00:00        5554.0       301.0
#               R             301 2017-06-27 01:00:00        5554.0       301.0
#               R             301 2017-06-27 05:00:00        5554.0       301.0
#               R             301 2017-06-27 09:00:00        5554.0       301.0
#               R             301 2017-06-27 13:00:00        5554.0       301.0
#               R             301 2017-06-27 17:00:00        5554.0       301.0
#               R             301 2017-06-27 21:00:00        5554.0       301.0
#               R             301 2017-06-28 01:00:00        5554.0       301.0
#               R             301 2017-06-28 05:00:00        5554.0       301.0
#               R             301 2017-06-28 09:00:00        5554.0       301.0
#               R             301 2017-06-28 13:00:00        5554.0       301.0
#               R             301 2017-06-28 17:00:00        5554.0       301.0
#               R             301 2017-06-28 21:00:00        5554.0       301.0
#               R             301 2017-06-29 01:00:00        5554.0       301.0
#               R             301 2017-06-29 05:00:00        5554.0       301.0
#               R             301 2017-06-29 09:00:00        5554.0       301.0
#               R             301 2017-06-29 13:00:00        5554.0       301.0
#               R             301 2017-06-29 17:00:00        5554.0       301.0
#               R             301 2017-06-29 21:00:00        5554.0       301.0
#               R             301 2017-06-30 01:00:00        5554.0       301.0
#               R             301 2017-06-30 05:00:00        5554.0       301.0
#               R             301 2017-06-30 07:17:19        5554.0       301.0
#               R             301 2017-06-30 09:00:00        5554.0       301.0
#               R             301 2017-06-30 13:00:00        5554.0       301.0
#               R             301 2017-06-30 17:00:00        5554.0       301.0
#
#                         HOURLY_ENTRIES  HOURLY_EXITS  TOTAL_TRAFFIC  DT_DIFF  \
# STATION       LINENAME
# 59 ST         456NQRW             22.0           4.0           26.0 04:00:00
#               456NQRW             14.0          30.0           44.0 04:00:00
#               456NQRW             81.0          83.0          164.0 04:00:00
#               456NQRW            218.0          58.0          276.0 04:00:00
#               456NQRW            284.0          49.0          333.0 04:00:00
#               456NQRW            145.0          25.0          170.0 04:00:00
#               456NQRW             16.0           5.0           21.0 04:00:00
#               456NQRW             15.0          20.0           35.0 04:00:00
#               456NQRW             70.0          69.0          139.0 04:00:00
#               456NQRW            206.0          45.0          251.0 04:00:00
#               456NQRW            167.0          32.0          199.0 04:00:00
#               456NQRW             91.0          17.0          108.0 04:00:00
#               456NQRW             13.0           2.0           15.0 04:00:00
#               456NQRW             44.0         116.0          160.0 04:00:00
#               456NQRW            160.0         278.0          438.0 04:00:00
#               456NQRW            285.0          58.0          343.0 04:00:00
#               456NQRW            660.0         121.0          781.0 04:00:00
#               456NQRW            197.0          32.0          229.0 04:00:00
#               456NQRW             20.0           0.0           20.0 04:00:00
#               456NQRW             60.0         115.0          175.0 04:00:00
#               456NQRW            254.0         253.0          507.0 04:00:00
#               456NQRW            409.0          75.0          484.0 04:00:00
#               456NQRW            819.0          68.0          887.0 04:00:00
#               456NQRW            219.0          27.0          246.0 04:00:00
#               456NQRW             16.0           2.0           18.0 04:00:00
#               456NQRW             70.0         122.0          192.0 04:00:00
#               456NQRW            226.0         254.0          480.0 04:00:00
#               456NQRW            469.0          76.0          545.0 04:00:00
#               456NQRW           1200.0          58.0         1258.0 04:00:00
#               456NQRW            380.0          16.0          396.0 04:00:00
# ...                                ...           ...            ...      ...
# RIT-ROOSEVELT R                    0.0           0.0            0.0 04:00:00
#               R                    0.0           0.0            0.0 04:00:00
#               R                    0.0           0.0            0.0 04:00:00
#               R                    0.0           0.0            0.0 04:00:00
#               R                    0.0           0.0            0.0 04:00:00
#               R                    0.0           0.0            0.0 04:00:00
#               R                    0.0           0.0            0.0 04:00:00
#               R                    0.0           0.0            0.0 04:00:00
#               R                    0.0           0.0            0.0 04:00:00
#               R                    0.0           0.0            0.0 04:00:00
#               R                    0.0           0.0            0.0 04:00:00
#               R                    0.0           0.0            0.0 04:00:00
#               R                    0.0           0.0            0.0 04:00:00
#               R                    0.0           0.0            0.0 04:00:00
#               R                    0.0           0.0            0.0 04:00:00
#               R                    0.0           0.0            0.0 04:00:00
#               R                    0.0           0.0            0.0 04:00:00
#               R                    0.0           0.0            0.0 04:00:00
#               R                    0.0           0.0            0.0 04:00:00
#               R                    0.0           0.0            0.0 04:00:00
#               R                    0.0           0.0            0.0 04:00:00
#               R                    0.0           0.0            0.0 04:00:00
#               R                    0.0           0.0            0.0 04:00:00
#               R                    0.0           0.0            0.0 04:00:00
#               R                    0.0           0.0            0.0 04:00:00
#               R                    0.0           0.0            0.0 02:17:19
#               R                    0.0           0.0            0.0 01:42:41
#               R                    0.0           0.0            0.0 04:00:00
#               R                    0.0           0.0            0.0 04:00:00
#               R                    0.0           0.0            0.0 04:00:00
#
#                               DOW  WEEKEND TOD
# STATION       LINENAME
# 59 ST         456NQRW    Saturday  Weekend  AM
#               456NQRW    Saturday  Weekend  AM
#               456NQRW    Saturday  Weekend  AM
#               456NQRW    Saturday  Weekend  PM
#               456NQRW    Saturday  Weekend  PM
#               456NQRW      Sunday  Weekend  AM
#               456NQRW      Sunday  Weekend  AM
#               456NQRW      Sunday  Weekend  AM
#               456NQRW      Sunday  Weekend  AM
#               456NQRW      Sunday  Weekend  PM
#               456NQRW      Sunday  Weekend  PM
#               456NQRW      Monday  Weekday  AM
#               456NQRW      Monday  Weekday  AM
#               456NQRW      Monday  Weekday  AM
#               456NQRW      Monday  Weekday  AM
#               456NQRW      Monday  Weekday  PM
#               456NQRW      Monday  Weekday  PM
#               456NQRW     Tuesday  Weekday  AM
#               456NQRW     Tuesday  Weekday  AM
#               456NQRW     Tuesday  Weekday  AM
#               456NQRW     Tuesday  Weekday  AM
#               456NQRW     Tuesday  Weekday  PM
#               456NQRW     Tuesday  Weekday  PM
#               456NQRW   Wednesday  Weekday  AM
#               456NQRW   Wednesday  Weekday  AM
#               456NQRW   Wednesday  Weekday  AM
#               456NQRW   Wednesday  Weekday  AM
#               456NQRW   Wednesday  Weekday  PM
#               456NQRW   Wednesday  Weekday  PM
#               456NQRW    Thursday  Weekday  AM
# ...                           ...      ...  ..
# RIT-ROOSEVELT R            Monday  Weekday  AM
#               R            Monday  Weekday  AM
#               R            Monday  Weekday  AM
#               R            Monday  Weekday  PM
#               R            Monday  Weekday  PM
#               R           Tuesday  Weekday  AM
#               R           Tuesday  Weekday  AM
#               R           Tuesday  Weekday  AM
#               R           Tuesday  Weekday  AM
#               R           Tuesday  Weekday  PM
#               R           Tuesday  Weekday  PM
#               R         Wednesday  Weekday  AM
#               R         Wednesday  Weekday  AM
#               R         Wednesday  Weekday  AM
#               R         Wednesday  Weekday  AM
#               R         Wednesday  Weekday  PM
#               R         Wednesday  Weekday  PM
#               R          Thursday  Weekday  AM
#               R          Thursday  Weekday  AM
#               R          Thursday  Weekday  AM
#               R          Thursday  Weekday  AM
#               R          Thursday  Weekday  PM
#               R          Thursday  Weekday  PM
#               R            Friday  Weekday  AM
#               R            Friday  Weekday  AM
#               R            Friday  Weekday  AM
#               R            Friday  Weekday  AM
#               R            Friday  Weekday  AM
#               R            Friday  Weekday  PM
#               R            Friday  Weekday  PM
#
# [784968 rows x 20 columns]

# %%
my_stations = top_real_stations
# my_zip = '11211'
# my_stations = top_stations[top_stations.short_zip==my_zip].STATION
# for station in my_stations:
mask = ((turnstiles_hourly.STA_LINE.isin(my_stations)))
df = turnstiles_hourly[mask].groupby(['STATION','LINENAME'], as_index=False).agg({'HOURLY_ENTRIES': 'sum','HOURLY_EXITS': 'sum'}) \
    .sort_values(by='HOURLY_ENTRIES', ascending=False)
df.rename(columns={'HOURLY_EXITS':'EXITS','HOURLY_ENTRIES': 'ENTRIES'}, inplace=True)
df.plot(kind='barh', figsize=(10,5), x=df.STATION +": "+ df.LINENAME, stacked=True);

# %%
top_real_stations = [
('HEWES STIM'),
('75 AVEF'),
('103 STBC'),
('SMITH-9 STFG'),
('UNION STR'),
('15 ST-PROSPECTFG'),
('67 AVMR'),
('GRAND STL'),
('72 STBC'),
('GRAHAM AVL'),
('7AVFG'),
('103 ST1'),
('MARCY AVIMZ'),
('FOREST HILLS 71EFMR'),
('KEW GARDENSEF'),
('33 ST6'),
('BEDFORD AVL'),
('72 ST123'),
('59 ST COLUMBUS1ABCD')]

# %%
turnstiles_hourly['STA_LINE'] = turnstiles_hourly.STATION + turnstiles_hourly.LINENAME

# %%
turnstiles_hourly.STA_LINE.head()
# Out:
# 1    59 ST456NQRW
# 2    59 ST456NQRW
# 3    59 ST456NQRW
# 4    59 ST456NQRW
# 5    59 ST456NQRW
# Name: STA_LINE, dtype: object
